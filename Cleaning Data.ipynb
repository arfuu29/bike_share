# %% [markdown]
# # Capstone Project Cyclistic Bike-Share

# %% [markdown]
# # Cleaning Proces
# <li>Import Package</li>
# <li>Handle Missing Value</li>
# <li>Handle duplicate data Handle irrelevant data</li>
# <li>Change the data type to match the data type</li>
# <li>Get insights from the data</li>
# <li>Export the data to a CSV file for analysis</li>

# %% [markdown]
# ## 1. Import Package
# Import pandas for cleaning data <br>
# import numpy for deal with NaN data <br>
# Import matplotlib for visualize data <br>

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
d_parser = lambda x: pd.datetime.strptime(x, format='%Y-%m-%d %H:%M:%S')

# %%
# Import CSV File from my computer
df = pd.read_csv('Downloads/Bike-Share data/Data/cylic/bike_data.csv', date_parser=d_parser)
# Out:
# C:\Users\Huawei\AppData\Local\Temp\ipykernel_29640\630381772.py:1: DtypeWarning: Columns (8,9,10,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('Downloads/Bike-Share data/Data/cylic/bike_data.csv', date_parser=d_parser)

# %%
# see row and column sizes
df.shape
# Out:
# (5829042, 13)

# %%
# Find Out Data Type every Columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5829042 entries, 0 to 5829041
# Data columns (total 13 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   ride_id             object
#  1   rideable_type       object
#  2   started_at          object
#  3   ended_at            object
#  4   start_station_name  object
#  5   start_station_id    object
#  6   end_station_name    object
#  7   end_station_id      object
#  8   start_lat           object
#  9   start_lng           object
#  10  end_lat             object
#  11  end_lng             object
#  12  member_casual       object
# dtypes: object(13)
# memory usage: 578.1+ MB

# %%
# Find out statistik about the dataset
# Find out duplicate, if there are more than two unique value on ride_id column, then there is duplicate data
df.describe()
# Out:
#         ride_id  rideable_type  started_at             ended_at  \
# count   5829042        5829041     5829041              5829041
# unique  5829032              4     4897046              4910591
# top     ride_id  electric_bike  started_at  2022-08-22 12:47:49
# freq         11        3083395          11                   20
#
#              start_station_name start_station_id         end_station_name  \
# count                   4994496          4994364                  4937284
# unique                     1896             1488                     1884
# top     Streeter Dr & Grand Ave            13022  Streeter Dr & Grand Ave
# freq                      73203            73203                    73626
#
#        end_station_id   start_lat   start_lng     end_lat     end_lng  \
# count         4937143  5829041.00  5829041.00  5823080.00  5823080.00
# unique           1469   903759.00   860675.00     6380.00     6371.00
# top             13022       41.89      -87.65       41.89      -87.65
# freq            73626    79952.00   118473.00    87966.00   127660.00
#
#        member_casual
# count        5829041
# unique             3
# top           member
# freq         3516957

# %%
# Filter duplicate and irrelevant data
filt = df['ride_id'] == 'ride_id'

# %%
df[filt]
# Out:
#          ride_id  rideable_type  started_at  ended_at  start_station_name  \
# 769204   ride_id  rideable_type  started_at  ended_at  start_station_name
# 1592693  ride_id  rideable_type  started_at  ended_at  start_station_name
# 2378626  ride_id  rideable_type  started_at  ended_at  start_station_name
# 3079966  ride_id  rideable_type  started_at  ended_at  start_station_name
# 3638652  ride_id  rideable_type  started_at  ended_at  start_station_name
# 3976388  ride_id  rideable_type  started_at  ended_at  start_station_name
# 4158195  ride_id  rideable_type  started_at  ended_at  start_station_name
# 4348497  ride_id  rideable_type  started_at  ended_at  start_station_name
# 4538943  ride_id  rideable_type  started_at  ended_at  start_station_name
# 4797622  ride_id  rideable_type  started_at  ended_at  start_station_name
# 5224213  ride_id  rideable_type  started_at  ended_at  start_station_name
#
#          start_station_id  end_station_name  end_station_id  start_lat  \
# 769204   start_station_id  end_station_name  end_station_id  start_lat
# 1592693  start_station_id  end_station_name  end_station_id  start_lat
# 2378626  start_station_id  end_station_name  end_station_id  start_lat
# 3079966  start_station_id  end_station_name  end_station_id  start_lat
# 3638652  start_station_id  end_station_name  end_station_id  start_lat
# 3976388  start_station_id  end_station_name  end_station_id  start_lat
# 4158195  start_station_id  end_station_name  end_station_id  start_lat
# 4348497  start_station_id  end_station_name  end_station_id  start_lat
# 4538943  start_station_id  end_station_name  end_station_id  start_lat
# 4797622  start_station_id  end_station_name  end_station_id  start_lat
# 5224213  start_station_id  end_station_name  end_station_id  start_lat
#
#          start_lng  end_lat  end_lng  member_casual
# 769204   start_lng  end_lat  end_lng  member_casual
# 1592693  start_lng  end_lat  end_lng  member_casual
# 2378626  start_lng  end_lat  end_lng  member_casual
# 3079966  start_lng  end_lat  end_lng  member_casual
# 3638652  start_lng  end_lat  end_lng  member_casual
# 3976388  start_lng  end_lat  end_lng  member_casual
# 4158195  start_lng  end_lat  end_lng  member_casual
# 4348497  start_lng  end_lat  end_lng  member_casual
# 4538943  start_lng  end_lat  end_lng  member_casual
# 4797622  start_lng  end_lat  end_lng  member_casual
# 5224213  start_lng  end_lat  end_lng  member_casual

# %%
df.head(10)
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  600CFD130D0FD2A4  electric_bike  2022-06-30 17:27:53  2022-06-30 17:35:15
# 1  F5E6B5C1682C6464  electric_bike  2022-06-30 18:39:52  2022-06-30 18:47:28
# 2  B6EB6D27BAD771D2  electric_bike  2022-06-30 11:49:25  2022-06-30 12:02:54
# 3  C9C320375DE1D5C6  electric_bike  2022-06-30 11:15:25  2022-06-30 11:19:43
# 4  56C055851023BE98  electric_bike  2022-06-29 23:36:50  2022-06-29 23:45:17
# 5  B664188E8163D045  electric_bike  2022-06-30 16:42:10  2022-06-30 16:58:22
# 6  338C05A3E90D619B  electric_bike  2022-06-30 18:39:07  2022-06-30 19:05:02
# 7  C037F5F4107788DE  electric_bike  2022-06-30 12:46:14  2022-06-30 14:12:48
# 8  C19B08D794D1C89E  electric_bike  2022-06-30 11:09:38  2022-06-30 11:10:25
# 9  6E9E3A041C14E960  electric_bike  2022-06-30 11:05:46  2022-06-30 11:09:11
#
#   start_station_name start_station_id end_station_name end_station_id  \
# 0                NaN              NaN              NaN            NaN
# 1                NaN              NaN              NaN            NaN
# 2                NaN              NaN              NaN            NaN
# 3                NaN              NaN              NaN            NaN
# 4                NaN              NaN              NaN            NaN
# 5                NaN              NaN              NaN            NaN
# 6                NaN              NaN              NaN            NaN
# 7                NaN              NaN              NaN            NaN
# 8                NaN              NaN              NaN            NaN
# 9                NaN              NaN              NaN            NaN
#
#   start_lat start_lng end_lat end_lng member_casual
# 0     41.89    -87.62   41.91  -87.62        casual
# 1     41.91    -87.62   41.93  -87.63        casual
# 2     41.91    -87.65   41.89  -87.61        casual
# 3      41.8    -87.66    41.8  -87.65        casual
# 4     41.91    -87.63   41.93  -87.64        casual
# 5     42.03    -87.71   42.06  -87.73        casual
# 6     41.91    -87.63   41.92  -87.72        casual
# 7     41.89    -87.62   41.98  -87.67        casual
# 8     41.89    -87.61   41.89  -87.61        casual
# 9     41.89    -87.61   41.89  -87.61        casual

# %% [markdown]
# ## 2. Handle Missing Value
#    At this stage, if a row has NaN values, then that row will be deleted. This is a bad habit; NaN values should be handled better by filling values with references from other matters. But after trying the NaN values in this project, it is tough to take; most of the data has more than 5 NaN values in 1 row. This stage succeeded in deleting approximately one million data from a total of 5.8 million data. This is a bad idea.

# %%
df1 = df.dropna()

# %%
# Show 20 rows after deleting NaN values
df1.head(20)
# Out:
#                ride_id  rideable_type           started_at  \
# 98    B12AD6565494C368   classic_bike  2022-06-09 22:28:32
# 137   BAD4CB075003A605  electric_bike  2022-06-19 17:08:23
# 214   76DAD9FC95774B53  electric_bike  2022-06-26 23:59:44
# 216   47DE68ACCA138C13  electric_bike  2022-06-27 11:40:53
# 233   5D899636D3334ED5   classic_bike  2022-06-27 16:01:13
# 387   7A163D957F8CF0DD   classic_bike  2022-06-19 22:29:14
# 396   32C67769462EDF7B   classic_bike  2022-06-20 16:24:51
# 408   ED5BCFCCF7BC19E0  electric_bike  2022-06-20 17:12:43
# 409   DC1BC5272DE7CA7E   classic_bike  2022-06-20 11:41:44
# 486   75978BEC3D8D47CB   classic_bike  2022-06-20 11:41:11
# 619   365504C710A7181C   classic_bike  2022-06-18 19:03:03
# 687   60155D824618922C   classic_bike  2022-06-12 11:19:41
# 737   B0DE5946B58F06AD   classic_bike  2022-06-12 15:09:43
# 747   69723D14EA8B4131  electric_bike  2022-06-11 19:49:40
# 756   CB0FEBEA54F9A9E0  electric_bike  2022-06-12 07:30:51
# 776   3E5EA18D6B97D61D   classic_bike  2022-06-15 20:50:44
# 857   275B6B72ABACD15A  electric_bike  2022-06-24 23:50:29
# 1015  A41AC2F1BB94DEF5   classic_bike  2022-06-16 11:24:14
# 1184  45A7B9995232F62D   classic_bike  2022-06-03 12:49:34
# 1359  F1CD71D4CC22D291   classic_bike  2022-06-27 10:44:46
#
#                  ended_at              start_station_name start_station_id  \
# 98    2022-06-09 22:52:17  California Ave & Milwaukee Ave            13084
# 137   2022-06-19 17:08:25  California Ave & Milwaukee Ave            13084
# 214   2022-06-27 00:25:26     Burnham Greenway & 105th St            20222
# 216   2022-06-27 11:50:16           Wood St & Chicago Ave              637
# 233   2022-06-27 16:35:56    California Ave & Division St            13256
# 387   2022-06-19 22:29:57  California Ave & Milwaukee Ave            13084
# 396   2022-06-20 16:33:39    California Ave & Division St            13256
# 408   2022-06-20 18:22:51            Morgan Ave & 14th Pl     TA1306000002
# 409   2022-06-20 13:33:47     Burnham Greenway & 105th St            20222
# 486   2022-06-20 13:33:50     Burnham Greenway & 105th St            20222
# 619   2022-06-18 20:02:10  California Ave & Milwaukee Ave            13084
# 687   2022-06-12 11:38:33  California Ave & Milwaukee Ave            13084
# 737   2022-06-12 15:10:20            Morgan Ave & 14th Pl     TA1306000002
# 747   2022-06-11 20:05:39  California Ave & Milwaukee Ave            13084
# 756   2022-06-12 07:32:20           Wood St & Chicago Ave              637
# 776   2022-06-15 20:54:56  California Ave & Milwaukee Ave            13084
# 857   2022-06-25 00:21:39  California Ave & Milwaukee Ave            13084
# 1015  2022-06-16 11:36:10     Burnham Greenway & 105th St            20222
# 1184  2022-06-03 12:51:33     Burnham Greenway & 105th St            20222
# 1359  2022-06-27 11:20:53           Wood St & Chicago Ave              637
#
#                     end_station_name end_station_id  start_lat  start_lng  \
# 98    California Ave & Milwaukee Ave          13084  41.922695 -87.697153
# 137   California Ave & Milwaukee Ave          13084  41.922613 -87.697148
# 214      Burnham Greenway & 105th St          20222  41.704628 -87.528414
# 216     California Ave & Division St          13256  41.895611 -87.672098
# 233     California Ave & Division St          13256  41.903029 -87.697474
# 387   California Ave & Milwaukee Ave          13084  41.922695 -87.697153
# 396   California Ave & Milwaukee Ave          13084  41.903029 -87.697474
# 408             Morgan Ave & 14th Pl   TA1306000002  41.862423 -87.651162
# 409      Burnham Greenway & 105th St          20222  41.704575 -87.528232
# 486      Burnham Greenway & 105th St          20222  41.704575 -87.528232
# 619   California Ave & Milwaukee Ave          13084  41.922695 -87.697153
# 687   California Ave & Milwaukee Ave          13084  41.922695 -87.697153
# 737             Morgan Ave & 14th Pl   TA1306000002  41.862378 -87.651062
# 747     California Ave & Division St          13256  41.922615 -87.697146
# 756            Wood St & Chicago Ave            637  41.895621  -87.67215
# 776   California Ave & Milwaukee Ave          13084  41.922695 -87.697153
# 857   California Ave & Milwaukee Ave          13084  41.922688 -87.697147
# 1015     Burnham Greenway & 105th St          20222  41.704575 -87.528232
# 1184     Burnham Greenway & 105th St          20222  41.704575 -87.528232
# 1359     Campbell Ave & Montrose Ave          15623  41.895634 -87.672069
#
#         end_lat    end_lng member_casual
# 98    41.922695 -87.697153        casual
# 137   41.922695 -87.697153        casual
# 214   41.704575 -87.528232        casual
# 216   41.903029 -87.697474        casual
# 233   41.903029 -87.697474        casual
# 387   41.922695 -87.697153        casual
# 396   41.922695 -87.697153        casual
# 408   41.862378 -87.651062        casual
# 409   41.704575 -87.528232        casual
# 486   41.704575 -87.528232        casual
# 619   41.922695 -87.697153        casual
# 687   41.922695 -87.697153        casual
# 737   41.862378 -87.651062        casual
# 747   41.903029 -87.697474        casual
# 756   41.895634 -87.672069        casual
# 776   41.922695 -87.697153        casual
# 857   41.922695 -87.697153        casual
# 1015  41.704575 -87.528232        casual
# 1184  41.704575 -87.528232        casual
# 1359  41.961526 -87.691165        casual

# %%
# Change Name Values of member_casual column
df1['member_casual'] = df1['member_casual'].replace(['member','casual'], ['annual_member', 'casual_ride'])
# Out:
# C:\Users\Huawei\AppData\Local\Temp\ipykernel_29640\2708632826.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['member_casual'] = df1['member_casual'].replace(['member','casual'], ['annual_member', 'casual_ride'])

# %%
# Cek values
df1['member_casual'].value_counts()
# Out:
# annual_member    2746774
# casual_ride      1747907
# member_casual         11
# Name: member_casual, dtype: int64

# %%
df1.shape
# Out:
# (4494692, 13)

# %%
# Cek duplicate data
df1.describe()
# Out:
#         ride_id rideable_type  started_at             ended_at  \
# count   4494692       4494692     4494692              4494692
# unique  4494682             4     3905894              3919338
# top     ride_id  classic_bike  started_at  2022-06-22 08:01:59
# freq         11       2584947          11                   14
#
#              start_station_name start_station_id         end_station_name  \
# count                   4494692          4494692                  4494692
# unique                     1746             1421                     1778
# top     Streeter Dr & Grand Ave            13022  Streeter Dr & Grand Ave
# freq                      69097            69097                    70613
#
#        end_station_id     start_lat     start_lng       end_lat       end_lng  \
# count         4494692  4.494692e+06  4.494692e+06  4.494692e+06  4.494692e+06
# unique           1425  7.928870e+05  7.562280e+05  5.044000e+03  5.034000e+03
# top             13022  4.189228e+01 -8.761204e+01  4.189228e+01 -8.761204e+01
# freq            70613  4.599500e+04  4.598800e+04  6.643100e+04  6.643100e+04
#
#         member_casual
# count         4494692
# unique              3
# top     annual_member
# freq          2746774

# %% [markdown]
# ## 3. Handle duplicate data
# In the dataset, there are duplicate data. Therefore we solve it with the drop_duplicate() function based on the ride_id column. Each row in the ride_id column must be unique because it represents one made trip.

# %%
df1.drop_duplicates('ride_id', inplace=True)
# Out:
# C:\Users\Huawei\AppData\Local\Temp\ipykernel_29640\4086205934.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.drop_duplicates('ride_id', inplace=True)

# %%
# Cek the dataset after drop duplicate
df1.describe()
# Out:
#                  ride_id rideable_type           started_at  \
# count            4494682       4494682              4494682
# unique           4494682             4              3905894
# top     B12AD6565494C368  classic_bike  2022-07-09 17:23:31
# freq                   1       2584947                    8
#
#                    ended_at       start_station_name start_station_id  \
# count               4494682                  4494682          4494682
# unique              3919338                     1746             1421
# top     2022-06-22 08:01:59  Streeter Dr & Grand Ave            13022
# freq                     14                    69097            69097
#
#                end_station_name end_station_id     start_lat     start_lng  \
# count                   4494682        4494682  4.494682e+06  4.494682e+06
# unique                     1778           1425  7.928870e+05  7.562280e+05
# top     Streeter Dr & Grand Ave          13022  4.189228e+01 -8.761204e+01
# freq                      70613          70613  4.599500e+04  4.598800e+04
#
#              end_lat       end_lng  member_casual
# count   4.494682e+06  4.494682e+06        4494682
# unique  5.044000e+03  5.034000e+03              3
# top     4.189228e+01 -8.761204e+01  annual_member
# freq    6.643100e+04  6.643100e+04        2746774

# %% [markdown]
# ## 3. Handle irrelevant data

# %%
#Cek count data use value_counts() function
df1['rideable_type'].value_counts()

# %%
# Create filter
filt = df1['rideable_type'] == 'rideable_type'

# %%
# Show irrelevant data
df1[filt]
# Out:
#         ride_id  rideable_type  started_at  ended_at  start_station_name  \
# 769204  ride_id  rideable_type  started_at  ended_at  start_station_name
#
#         start_station_id  end_station_name  end_station_id  start_lat  \
# 769204  start_station_id  end_station_name  end_station_id  start_lat
#
#         start_lng  end_lat  end_lng  member_casual
# 769204  start_lng  end_lat  end_lng  member_casual

# %%
i = df1[(df1.ride_id == 'ride_id')].index

# %%
# Drop irrelevant data
df1.drop(i, inplace=True)
# Out:
# C:\Users\Huawei\AppData\Local\Temp\ipykernel_29640\3752426791.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.drop(i, inplace=True)

# %%
# Cek statistik summary
df1.describe()
# Out:
#                  ride_id rideable_type           started_at  \
# count            4494681       4494681              4494681
# unique           4494681             3              3905893
# top     B12AD6565494C368  classic_bike  2022-07-09 17:23:31
# freq                   1       2584947                    8
#
#                    ended_at       start_station_name start_station_id  \
# count               4494681                  4494681          4494681
# unique              3919337                     1745             1420
# top     2022-06-22 08:01:59  Streeter Dr & Grand Ave            13022
# freq                     14                    69097            69097
#
#                end_station_name end_station_id     start_lat     start_lng  \
# count                   4494681        4494681  4.494681e+06  4.494681e+06
# unique                     1777           1424  7.928860e+05  7.562270e+05
# top     Streeter Dr & Grand Ave          13022  4.189228e+01 -8.761204e+01
# freq                      70613          70613  4.599500e+04  4.598800e+04
#
#              end_lat       end_lng  member_casual
# count   4.494681e+06  4.494681e+06        4494681
# unique  5.043000e+03  5.033000e+03              2
# top     4.189228e+01 -8.761204e+01  annual_member
# freq    6.643100e+04  6.643100e+04        2746774

# %% [markdown]
# ## 4. Change the data type to match the data type
# We will convert the data type of the "started_at" and "ended_at" columns to datetime. Additionally, we will change the data type of the geo location coordinates - "start_lat", "start_lng", "end_lat", and "end_lng" - to float in order to adjust the number of decimals.

# %%
# Cek column data type
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5829042 entries, 0 to 5829041
# Data columns (total 13 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   ride_id             object
#  1   rideable_type       object
#  2   started_at          object
#  3   ended_at            object
#  4   start_station_name  object
#  5   start_station_id    object
#  6   end_station_name    object
#  7   end_station_id      object
#  8   start_lat           object
#  9   start_lng           object
#  10  end_lat             object
#  11  end_lng             object
#  12  member_casual       object
# dtypes: object(13)
# memory usage: 578.1+ MB

# %%
# Change data type from object to datatime
df1['started_at'] = pd.to_datetime(df1['started_at'])
df1['ended_at'] = pd.to_datetime(df1['ended_at'], errors='coerce')
# Out:
# C:\Users\Huawei\AppData\Local\Temp\ipykernel_29640\1366607361.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['started_at'] = pd.to_datetime(df1['started_at'])
# C:\Users\Huawei\AppData\Local\Temp\ipykernel_29640\1366607361.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['ended_at'] = pd.to_datetime(df1['ended_at'], errors='coerce')

# %%
# Change data type from object to float
df1['start_lat'] = df1['start_lat'].astype(float)
df1['start_lng'] = df1['start_lng'].astype(float)
df1['end_lat'] = df1['end_lat'].astype(float)
df1['end_lng'] = df1['end_lng'].astype(float)
# Out:
# C:\Users\Huawei\AppData\Local\Temp\ipykernel_29640\3333496222.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['start_lat'] = df1['start_lat'].astype(float)
# C:\Users\Huawei\AppData\Local\Temp\ipykernel_29640\3333496222.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['start_lng'] = df1['start_lng'].astype(float)
# C:\Users\Huawei\AppData\Local\Temp\ipykernel_29640\3333496222.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['end_lat'] = df1['end_lat'].astype(float)
# C:\Users\Huawei\AppData\Local\Temp\ipykernel_29640\3333496222.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['end_lng'] = df1['end_lng'].astype(float)

# %%
# Cek datatype
df1.dtypes
# Out:
# ride_id                       object
# rideable_type                 object
# started_at            datetime64[ns]
# ended_at              datetime64[ns]
# start_station_name            object
# start_station_id              object
# end_station_name              object
# end_station_id                object
# start_lat                    float64
# start_lng                    float64
# end_lat                      float64
# end_lng                      float64
# member_casual                 object
# dtype: object

# %% [markdown]
# ## 5. Get insights from the data

# %%
count_ride_type
# Out:
# classic_bike     0.575112
# electric_bike    0.390515
# docked_bike      0.034373
# Name: rideable_type, dtype: float64

# %%
## Insight about ride type and member type
data_count = [df1['rideable_type'].value_counts(normalize=True),df1['member_casual'].value_counts()]
for i in data_count:
    plt.figure()
    plt.style.use('ggplot')
    i.plot(kind='pie', label='')

# %%
## Insight about top station start and top station end
station_data = [df1['start_station_name'].value_counts().head(10), df1['end_station_name'].value_counts().head(10)]
for i in station_data:
    plt.figure()
    plt.style.use('ggplot')
    i.plot(kind='barh')

# %% [markdown]
# ## 6. Export the data to a CSV file for analysis.

# %%
df1.to_csv('C:\\Users\\Huawei\\Downloads\\Bike-Share data\\Data\\cylic\\bike_share.csv', index=False)
